# %% [markdown]
# # TNM112 -- Lab 1
# Instructions about the different tasks are specified in this notebook. However, for more details, please see the PDF with lab instructions. Also see the lab report template for information on how to report your results.

# %% [markdown]
# ### Data generation
# Look through the "data_generator.py" code to understand how the dataset is generated and plotted.
#
# The "importlib" library is used to enable reloading of a library each time the cell is executed (so that changes to the imported script will be visible without restarting the notebook).

# %%
import importlib
import data_generator
importlib.reload(data_generator)

data = data_generator.DataGenerator()
data.generate(dataset='linear', N_train=32, N_test=512, K=4, sigma=0.4)
data.plot()
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      4
# 	Std of classes:         0.4
# 	Training data shape:    (128, 2)
# 	Validation data shape:  (2048, 2)
# 	Test data shape:        (2048, 2)

# %% [markdown]
# ### Keras MLP
# Look through the "keras_mlp.py" code to understand how the model is setup and trained.
#
# #### Task 1.1
# Use a linear dataset with N_train = 512 and K = 2. Specify a network without hidden layers. Compare:
# * Training for 4 epochs with learning rate 1.0 and batch size 512
# * Training for 4 epochs with learning rate 1.0 and batch size 16
#
# Answer the following questions:
# * Which model is best at separating the two classes (provide the accuracy on the test set)? Why is this the case? (Hint: how many iterations of SGD are performed in the two cases?)
# * Why is it possible to do the classification without non-linear activation function (there's only a softmax activation)?
#
# #### Task 1.2
# Use a polar dataset with N_train = 512 and K = 2. Specify a network with one hidden layer with 5 neurons. Train for 20 epochs with learning rate 1.0 and batch size 16. Compare:
# * Using linear activation function
# * Using sigmoid activation function
# * Using relu activation function
#
# Answer the following questions:
# * Why does linear activation not work?
# * On average, what is the best classification accuracy that can be achieved with a linear activation function?
# * Can you find an explanation for the difference comparing sigmoid and relu activation?
#
# #### Task 1.3
# Use a polar dataset with N_train = 512, K = 5, and sigma=0.05. Specify a network with 10 hidden layers with 50 neurons each and relu activation. Try different combinations of hyper parameters to get the best classification accuracy. Examples could be:
# * Change mean and stddev of normal initialization.
# * Change learning rate and add some momentum in SGD.
# * Check the Keras documentation for 'ExponentialDecay', which can be used to specify decaying learning rate for SGD.
# * You can also tweak batch size and number of epochs.
#
# What combination worked best, and what was your best classification accuracy (on the test set)? Can you find any patterns in what combinations of hyper parameters work and doesn't work?
#
# #### Task 1.4
# Continue from previous task, but change initialization to 'glorot_normal' and optimizer to 'keras.optimizers.Adam()'. Does this perform better compared to your results in Task 1.3?

# %%
import keras_mlp
importlib.reload(keras_mlp) 

from tensorflow import keras

# Uncomment to be able to change data specification (instead of having to run the above cell every time)
data.generate(dataset='linear', N_train=512, N_test=512, K=2, sigma=0.1) # Task 1.1
#data.generate(dataset='polar', N_train=512, N_test=512, K=2, sigma=0.1)  # Task 1.2
#data.generate(dataset='polar', N_train=512, N_test=512, K=5, sigma=0.05) # Task 1.3

# Hyper-parameters
hidden_layers = 10     # The number of hidden layers in the network (total number of layers will be L=hidden_layers+1)
layer_width = 50       # The number of neurons in each hidden layer
activation = 'relu' # Activation function of hidden layers
#init = keras.initializers.RandomNormal(mean=0.01, stddev=0.1) # Initialization method (starting point for the optimization)
init = keras.initializers.glorot_normal(seed = None)
epochs = 120           # Number of epochs for the training
# batch_size = 512      # Batch size to use in training
batch_size = 32
loss = keras.losses.MeanSquaredError() # Loss function

#initial_learning_rate = 0.01
#decay = keras.optimizers.schedules.ExponentialDecay(
#    initial_learning_rate,
#    decay_steps=100000,
#    decay_rate=0.96,
#    staircase=True)


#opt = keras.optimizers.SGD(learning_rate=decay, momentum=0.9) # Optimizer

opt = keras.optimizers.Adam(learning_rate=0.001)

# The Keras MLP model
model_k = keras_mlp.KerasMLP(data, verbose=True)

# Setup the model with the specified hyper parameters
model_k.setup_model(hidden_layers=hidden_layers, layer_width=layer_width,
                    activation=activation, init=init)

# Compile the model with a loss function and optimizer
model_k.compile(loss_fn=loss, optimizer=opt)

# Train the model a certain number of epochs with a specified batch size
model_k.train(epochs=epochs, batch_size=batch_size)

# Plot the training progress
model_k.plot_training()

# Evaluate the model (loss and accuracy on the training and test data)
model_k.evaluate()

# Plot the dataset with decision boundaries generated by the trained model
data.plot_classifier(model_k)
# Out:
# Data specification:
# 	Dataset type:           linear
# 	Number of classes:      2
# 	Std of classes:         0.1
# 	Training data shape:    (1024, 2)
# 	Validation data shape:  (1024, 2)
# 	Test data shape:        (1024, 2)
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 50)                150
#
#  dense_1 (Dense)             (None, 50)                2550
#
#  dense_2 (Dense)             (None, 50)                2550
#
#  dense_3 (Dense)             (None, 50)                2550
#
#  dense_4 (Dense)             (None, 50)                2550
#
#  dense_5 (Dense)             (None, 50)                2550
#
#  dense_6 (Dense)             (None, 50)                2550
#
#  dense_7 (Dense)             (None, 50)                2550
#
#  dense_8 (Dense)             (None, 50)                2550
#
#  dense_9 (Dense)             (None, 50)                2550
#
#  dense_10 (Dense)            (None, 2)                 102
#
# =================================================================
# Total params: 23202 (90.63 KB)
# Trainable params: 23202 (90.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# /Users/filiphamrelius/.pyenv/versions/3.8.16/lib/python3.8/site-packages/keras/src/initializers/initializers.py:120: UserWarning: The initializer GlorotNormal is unseeded and being called multiple times, which will return identical values each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initializer instance more than once.
#   warnings.warn(
# Epoch 1/120
# 32/32 [==============================] - 3s 14ms/step - loss: 0.2304 - accuracy: 0.6562 - val_loss: 0.1629 - val_accuracy: 0.8926
# Epoch 2/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0563 - accuracy: 0.9688 - val_loss: 0.0205 - val_accuracy: 0.9756
# Epoch 3/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0121 - accuracy: 0.9834 - val_loss: 0.0088 - val_accuracy: 0.9893
# Epoch 4/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9902 - val_loss: 0.0095 - val_accuracy: 0.9883
# Epoch 5/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0118 - accuracy: 0.9814 - val_loss: 0.0050 - val_accuracy: 0.9941
# Epoch 6/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9863 - val_loss: 0.0061 - val_accuracy: 0.9912
# Epoch 7/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0116 - accuracy: 0.9834 - val_loss: 0.0312 - val_accuracy: 0.9619
# Epoch 8/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0164 - accuracy: 0.9785 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 9/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9902 - val_loss: 0.0059 - val_accuracy: 0.9922
# Epoch 10/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9893 - val_loss: 0.0055 - val_accuracy: 0.9932
# Epoch 11/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9893 - val_loss: 0.0066 - val_accuracy: 0.9902
# Epoch 12/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9863 - val_loss: 0.0059 - val_accuracy: 0.9912
# Epoch 13/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0080 - accuracy: 0.9912 - val_loss: 0.0051 - val_accuracy: 0.9941
# Epoch 14/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0056 - accuracy: 0.9941 - val_loss: 0.0125 - val_accuracy: 0.9854
# Epoch 15/120
# 32/32 [==============================] - 0s 8ms/step - loss: 0.0096 - accuracy: 0.9863 - val_loss: 0.0064 - val_accuracy: 0.9912
# Epoch 16/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9893 - val_loss: 0.0059 - val_accuracy: 0.9932
# Epoch 17/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0077 - accuracy: 0.9893 - val_loss: 0.0147 - val_accuracy: 0.9805
# Epoch 18/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0076 - accuracy: 0.9922 - val_loss: 0.0086 - val_accuracy: 0.9893
# Epoch 19/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0065 - accuracy: 0.9922 - val_loss: 0.0051 - val_accuracy: 0.9922
# Epoch 20/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9912 - val_loss: 0.0055 - val_accuracy: 0.9922
# Epoch 21/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0074 - accuracy: 0.9902 - val_loss: 0.0069 - val_accuracy: 0.9922
# Epoch 22/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0103 - accuracy: 0.9854 - val_loss: 0.0148 - val_accuracy: 0.9795
# Epoch 23/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0098 - accuracy: 0.9883 - val_loss: 0.0071 - val_accuracy: 0.9922
# Epoch 24/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9893 - val_loss: 0.0052 - val_accuracy: 0.9932
# Epoch 25/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9873 - val_loss: 0.0053 - val_accuracy: 0.9922
# Epoch 26/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0079 - accuracy: 0.9893 - val_loss: 0.0050 - val_accuracy: 0.9932
# Epoch 27/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9893 - val_loss: 0.0059 - val_accuracy: 0.9932
# Epoch 28/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9912 - val_loss: 0.0049 - val_accuracy: 0.9932
# Epoch 29/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0107 - accuracy: 0.9854 - val_loss: 0.0089 - val_accuracy: 0.9893
# Epoch 30/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9922 - val_loss: 0.0053 - val_accuracy: 0.9932
# Epoch 31/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9863 - val_loss: 0.0051 - val_accuracy: 0.9932
# Epoch 32/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9902 - val_loss: 0.0055 - val_accuracy: 0.9922
# Epoch 33/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9893 - val_loss: 0.0089 - val_accuracy: 0.9902
# Epoch 34/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9912 - val_loss: 0.0062 - val_accuracy: 0.9922
# Epoch 35/120
# 32/32 [==============================] - 0s 5ms/step - loss: 0.0072 - accuracy: 0.9912 - val_loss: 0.0158 - val_accuracy: 0.9805
# Epoch 36/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0116 - accuracy: 0.9863 - val_loss: 0.0061 - val_accuracy: 0.9932
# Epoch 37/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0126 - accuracy: 0.9834 - val_loss: 0.0190 - val_accuracy: 0.9795
# Epoch 38/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9912 - val_loss: 0.0068 - val_accuracy: 0.9922
# Epoch 39/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9834 - val_loss: 0.0119 - val_accuracy: 0.9854
# Epoch 40/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9893 - val_loss: 0.0054 - val_accuracy: 0.9932
# Epoch 41/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9863 - val_loss: 0.0068 - val_accuracy: 0.9932
# Epoch 42/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9902 - val_loss: 0.0060 - val_accuracy: 0.9922
# Epoch 43/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9922 - val_loss: 0.0116 - val_accuracy: 0.9854
# Epoch 44/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0105 - accuracy: 0.9844 - val_loss: 0.0070 - val_accuracy: 0.9922
# Epoch 45/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9922 - val_loss: 0.0064 - val_accuracy: 0.9932
# Epoch 46/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0069 - accuracy: 0.9912 - val_loss: 0.0069 - val_accuracy: 0.9922
# Epoch 47/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9902 - val_loss: 0.0108 - val_accuracy: 0.9863
# Epoch 48/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9902 - val_loss: 0.0058 - val_accuracy: 0.9932
# Epoch 49/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9883 - val_loss: 0.0156 - val_accuracy: 0.9766
# Epoch 50/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0082 - accuracy: 0.9902 - val_loss: 0.0063 - val_accuracy: 0.9922
# Epoch 51/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9922 - val_loss: 0.0069 - val_accuracy: 0.9922
# Epoch 52/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9922 - val_loss: 0.0088 - val_accuracy: 0.9902
# Epoch 53/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9912 - val_loss: 0.0080 - val_accuracy: 0.9844
# Epoch 54/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9922 - val_loss: 0.0066 - val_accuracy: 0.9922
# Epoch 55/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9922 - val_loss: 0.0065 - val_accuracy: 0.9932
# Epoch 56/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0113 - accuracy: 0.9863 - val_loss: 0.0061 - val_accuracy: 0.9902
# Epoch 57/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9893 - val_loss: 0.0055 - val_accuracy: 0.9922
# Epoch 58/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9912 - val_loss: 0.0071 - val_accuracy: 0.9922
# Epoch 59/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9902 - val_loss: 0.0062 - val_accuracy: 0.9922
# Epoch 60/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9902 - val_loss: 0.0098 - val_accuracy: 0.9883
# Epoch 61/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0108 - accuracy: 0.9863 - val_loss: 0.0058 - val_accuracy: 0.9941
# Epoch 62/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0088 - accuracy: 0.9893 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 63/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9912 - val_loss: 0.0122 - val_accuracy: 0.9863
# Epoch 64/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9893 - val_loss: 0.0066 - val_accuracy: 0.9932
# Epoch 65/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0068 - accuracy: 0.9922 - val_loss: 0.0081 - val_accuracy: 0.9922
# Epoch 66/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9932 - val_loss: 0.0076 - val_accuracy: 0.9922
# Epoch 67/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0065 - accuracy: 0.9932 - val_loss: 0.0052 - val_accuracy: 0.9932
# Epoch 68/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0090 - accuracy: 0.9893 - val_loss: 0.0051 - val_accuracy: 0.9941
# Epoch 69/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0087 - accuracy: 0.9873 - val_loss: 0.0182 - val_accuracy: 0.9707
# Epoch 70/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9873 - val_loss: 0.0055 - val_accuracy: 0.9932
# Epoch 71/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0091 - accuracy: 0.9873 - val_loss: 0.0064 - val_accuracy: 0.9932
# Epoch 72/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9912 - val_loss: 0.0075 - val_accuracy: 0.9922
# Epoch 73/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0093 - accuracy: 0.9863 - val_loss: 0.0060 - val_accuracy: 0.9922
# Epoch 74/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9902 - val_loss: 0.0080 - val_accuracy: 0.9922
# Epoch 75/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0081 - accuracy: 0.9893 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 76/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9883 - val_loss: 0.0076 - val_accuracy: 0.9922
# Epoch 77/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9922 - val_loss: 0.0058 - val_accuracy: 0.9922
# Epoch 78/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9932 - val_loss: 0.0094 - val_accuracy: 0.9902
# Epoch 79/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9912 - val_loss: 0.0052 - val_accuracy: 0.9932
# Epoch 80/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0080 - accuracy: 0.9883 - val_loss: 0.0053 - val_accuracy: 0.9941
# Epoch 81/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9912 - val_loss: 0.0069 - val_accuracy: 0.9863
# Epoch 82/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9893 - val_loss: 0.0073 - val_accuracy: 0.9922
# Epoch 83/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9902 - val_loss: 0.0073 - val_accuracy: 0.9912
# Epoch 84/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9902 - val_loss: 0.0150 - val_accuracy: 0.9834
# Epoch 85/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9893 - val_loss: 0.0055 - val_accuracy: 0.9941
# Epoch 86/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0092 - accuracy: 0.9863 - val_loss: 0.0104 - val_accuracy: 0.9814
# Epoch 87/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9893 - val_loss: 0.0065 - val_accuracy: 0.9922
# Epoch 88/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9893 - val_loss: 0.0053 - val_accuracy: 0.9932
# Epoch 89/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9912 - val_loss: 0.0083 - val_accuracy: 0.9912
# Epoch 90/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0097 - accuracy: 0.9883 - val_loss: 0.0059 - val_accuracy: 0.9922
# Epoch 91/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0079 - accuracy: 0.9893 - val_loss: 0.0078 - val_accuracy: 0.9922
# Epoch 92/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0075 - accuracy: 0.9883 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 93/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9902 - val_loss: 0.0055 - val_accuracy: 0.9932
# Epoch 94/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0072 - accuracy: 0.9902 - val_loss: 0.0058 - val_accuracy: 0.9941
# Epoch 95/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9893 - val_loss: 0.0056 - val_accuracy: 0.9941
# Epoch 96/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0089 - accuracy: 0.9893 - val_loss: 0.0083 - val_accuracy: 0.9912
# Epoch 97/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9902 - val_loss: 0.0061 - val_accuracy: 0.9922
# Epoch 98/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9912 - val_loss: 0.0054 - val_accuracy: 0.9922
# Epoch 99/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9922 - val_loss: 0.0063 - val_accuracy: 0.9912
# Epoch 100/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0076 - accuracy: 0.9902 - val_loss: 0.0054 - val_accuracy: 0.9951
# Epoch 101/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9902 - val_loss: 0.0053 - val_accuracy: 0.9932
# Epoch 102/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0078 - accuracy: 0.9902 - val_loss: 0.0049 - val_accuracy: 0.9941
# Epoch 103/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0073 - accuracy: 0.9922 - val_loss: 0.0051 - val_accuracy: 0.9941
# Epoch 104/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9912 - val_loss: 0.0053 - val_accuracy: 0.9922
# Epoch 105/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9922 - val_loss: 0.0063 - val_accuracy: 0.9922
# Epoch 106/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0063 - accuracy: 0.9902 - val_loss: 0.0063 - val_accuracy: 0.9932
# Epoch 107/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0060 - accuracy: 0.9932 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 108/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0086 - accuracy: 0.9902 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 109/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9932 - val_loss: 0.0062 - val_accuracy: 0.9922
# Epoch 110/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0055 - accuracy: 0.9922 - val_loss: 0.0121 - val_accuracy: 0.9863
# Epoch 111/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0085 - accuracy: 0.9883 - val_loss: 0.0052 - val_accuracy: 0.9941
# Epoch 112/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9922 - val_loss: 0.0095 - val_accuracy: 0.9893
# Epoch 113/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0071 - accuracy: 0.9912 - val_loss: 0.0106 - val_accuracy: 0.9893
# Epoch 114/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0070 - accuracy: 0.9922 - val_loss: 0.0060 - val_accuracy: 0.9922
# Epoch 115/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9902 - val_loss: 0.0093 - val_accuracy: 0.9893
# Epoch 116/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0064 - accuracy: 0.9922 - val_loss: 0.0056 - val_accuracy: 0.9922
# Epoch 117/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0083 - accuracy: 0.9873 - val_loss: 0.0056 - val_accuracy: 0.9941
# Epoch 118/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0067 - accuracy: 0.9893 - val_loss: 0.0054 - val_accuracy: 0.9922
# Epoch 119/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9922 - val_loss: 0.0076 - val_accuracy: 0.9912
# Epoch 120/120
# 32/32 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9902 - val_loss: 0.0063 - val_accuracy: 0.9922
# Model performance:
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0058 - accuracy: 0.9922
# 	Train loss:     0.0058
# 	Train accuracy: 99.22
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0078 - accuracy: 0.9912
# 	Test loss:      0.0078
# 	Test accuracy:  99.12
# 32/32 [==============================] - 0s 1ms/step
# 512/512 [==============================] - 1s 1ms/step

# %% [markdown]
# ### Our MLP
# To make sure our implementation of the MLP works as intended, we can run inference using the weights we trained with Keras. Then we can see if we get the same results in terms of accuracy and the decision boundaries generated by the model.
#
# #### Task 2
# Implement the "activation", "setup_model", "feedforward", and "evaluate" functions in "mlp.py". Run this cell and compare the results to the results generated by the Keras model in the previous cell (compare number of weights, classification loss/accuracy, and the plots with decision boundaries). Test this for different specifications of the model in the previous cell (number of hidden layers, layer width, and activation function)
#
# #### Task 3
# Use the linear dataset with 2 classes (K=2). Change the specification of the model parameters. Instead of extracting the weights from the Keras model, you should manually specify a weight matrix (2x2) and a bias vector (2x1), i.e. no hidden layers. Remember that each layer is supposed to be an item in a list, which means that you need to specify the weight matrix and the bias vector in separate 1-item lists. As we only have one layer, it will use the 'softmax' activation function.
# * Manually derive weights and biases to specify a model that draws a decision boundary at x2 = 1-x1. What is the simplest possible solution? How many additional solutions are possible?
# * How can you, in the simplest way, change the weights/biases to switch the predicted class labels?
# * By writing out the output of the MLP, motivate why your choice of weights and biases creates a decision boundary at x2 = 1-x1. Can you find a general formula for specifying which combinations of weights and biases will generate the decision boundary?

# %%
import numpy as np
import mlp
importlib.reload(mlp)

# Get the weight matrices and biases of the trained Keras model
W, b = model_k.get_weights()

# Task 3: specify a weight matrix and a bias vector
#W = [np.random.randn(2, 2)]  
#b = [np.random.randn(2)]     


# Flipping the signs on both W and b gives the inverse. 

# This is our implementation of an MLP, which we set to use the dataset we generated
model = mlp.MLP(data)

# Assign the weights and biases to the MLP and specify the activation function
model.setup_model(W, b, activation=activation)

# Evaluate the model (accuracy on the training and test data)
model.evaluate()

# Plot the dataset with decision boundaries generated by our MLP
data.plot_classifier(model)
# Out:
# Number of hidden layers:  10
# Number of model weights:  550
# Model performance:
# 	Train loss:     0.0127
# 	Train accuracy: 0.99
# 	Test loss:      0.0142
# 	Test accuracy:  0.99
